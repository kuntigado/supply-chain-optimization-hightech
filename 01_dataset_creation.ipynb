# %%
import pandas as pd
import numpy as np

np.random.seed(42)
n = 50

df = pd.DataFrame({
    'supplier_id': [f'SUP_{i:03d}' for i in range(1, n+1)],
    'component_type': np.random.choice(
        ['Optical', 'Mechanical', 'Electronic', 'Pneumatic'], n),
    'lead_time_days': np.random.randint(14, 120, n),
    'lead_time_std_dev': np.random.randint(2, 20, n),
    'unit_cost_eur': np.random.randint(500, 50000, n),
    'on_time_delivery_rate': np.round(np.random.uniform(0.7, 1.0, n), 2),
    'defect_rate': np.round(np.random.uniform(0.01, 0.10, n), 3),
    'single_source': np.random.choice([True, False], n),
    'country': np.random.choice(
        ['Netherlands', 'Germany', 'Japan', 'USA', 'Taiwan'], n),
    'criticality': np.random.choice(['High', 'Medium', 'Low'], n)
})

# %%
df.head()
# Out:
#   supplier_id component_type  lead_time_days  lead_time_std_dev  \
# 0     SUP_001     Electronic              60                 15
# 1     SUP_002      Pneumatic              75                 17
# 2     SUP_003        Optical              64                 16
# 3     SUP_004     Electronic              68                  9
# 4     SUP_005     Electronic              77                 15
#
#    unit_cost_eur  on_time_delivery_rate  defect_rate  single_source  \
# 0          33770                   0.86        0.071           True
# 1           7410                   0.85        0.076          False
# 2          45953                   0.91        0.029           True
# 3          25946                   0.78        0.059          False
# 4            706                   0.77        0.073           True
#
#        country criticality
# 0      Germany        High
# 1  Netherlands         Low
# 2      Germany      Medium
# 3      Germany        High
# 4        Japan      Medium

# %%
df.groupby(["country","criticality"])["component_type"].count()
# Out:
# country      criticality
# Germany      High           8
#              Low            4
#              Medium         6
# Japan        High           1
#              Low            2
#              Medium         4
# Netherlands  High           2
#              Low            5
#              Medium         3
# Taiwan       High           3
#              Low            2
#              Medium         1
# USA          High           4
#              Low            3
#              Medium         2
# Name: component_type, dtype: int64

# %%
df.dtypes
# Out:
# supplier_id               object
# component_type            object
# lead_time_days             int32
# lead_time_std_dev          int32
# unit_cost_eur              int32
# on_time_delivery_rate    float64
# defect_rate              float64
# single_source               bool
# country                   object
# criticality               object
# dtype: object

# %%
df.groupby(["country"],sort=False)["criticality"].count()
# Out:
# country
# Germany        18
# Netherlands    10
# Japan           7
# Taiwan          6
# USA             9
# Name: criticality, dtype: int64

# %%
df.groupby(["component_type"])["unit_cost_eur"].mean().sort_values(ascending = False)
# Out:
# component_type
# Mechanical    35653.272727
# Electronic    24305.538462
# Pneumatic     23956.750000
# Optical       23340.100000
# Name: unit_cost_eur, dtype: float64

# %%
df["lead_time_days"].max()
# Out:
# 119

# %%
df.iloc[df["lead_time_days"].argmax()]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
# supplier_id              SUP_039
# component_type           Optical
# lead_time_days               119
# lead_time_std_dev              4
# unit_cost_eur              10730
# on_time_delivery_rate       0.91
# defect_rate                0.043
# single_source              False
# country                  Germany
# criticality                 High
# Name: 38, dtype: object

# %%
df.iloc[df["lead_time_days"].argmin()]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   """Entry point for launching an IPython kernel.
# supplier_id                  SUP_021
# component_type            Mechanical
# lead_time_days                    15
# lead_time_std_dev                 12
# unit_cost_eur                  28390
# on_time_delivery_rate            0.8
# defect_rate                     0.09
# single_source                  False
# country                  Netherlands
# criticality                   Medium
# Name: 20, dtype: object
